# %% [markdown]
# # Notebook XSS test
# <img src=x onerror="document.title='PWNEDNB1'">

# %%
# raw HTML output cell test
# Out:
# <img src=x onerror="document.title='PWNEDNB2'"><svg onload="document.title='PWNEDNB3'"><iframe srcdoc="&lt;script&gt;parent.document.title='PWNEDNB4'&lt;/script&gt;"></iframe><details open ontoggle="document.title='PWNEDNB5'">x</details>
