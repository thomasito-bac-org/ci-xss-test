# %%
# data: URI scheme test
# Out:
# <a href="data:text/html,<script>document.title='DATAURI1'</script>">click1</a><iframe src="data:text/html,<script>parent.document.title='DATAURI2'</script>"></iframe><object data="data:text/html,<script>document.title='DATAURI3'</script>"></object><embed src="data:text/html,<script>document.title='DATAURI4'</script>"><img src="data:image/svg+xml,<svg xmlns='http://www.w3.org/2000/svg' onload='document.title="DATAURI5"'></svg>">
